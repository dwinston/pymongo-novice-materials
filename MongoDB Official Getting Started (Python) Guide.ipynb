# %% [markdown]
# This notebook is to see how far one can go through MongoDB's official [Python tutorial](https://docs.mongodb.org/getting-started/python/) using only `mongomock` and without a running MongoDB instance.

# %%
from mongomock import MongoClient

restaurants = MongoClient().db.collection

# %%
import json

# The "primer-dataset.json" file used in the official tutorial is not actually valid JSON.
# Rather, it is a file with one JS object per line, which is the format expected by `mongoimport`.
dataset = []
with open('data/primer-dataset.json') as f:
    for line in f:
        dataset.append(json.loads(line))

restaurants.insert_many(dataset)

# %%
restaurants.count()
# Out:
# 25359

# %%
from datetime import datetime
result = restaurants.insert_one(
    {
        "address": {
            "street": "2 Avenue",
            "zipcode": "10075",
            "building": "1480",
            "coord": [-73.9557413, 40.7720266]
        },
        "borough": "Manhattan",
        "cuisine": "Italian",
        "grades": [
            {
                "date": datetime.strptime("2014-10-01", "%Y-%m-%d"),
                "grade": "A",
                "score": 11
            },
            {
                "date": datetime.strptime("2014-01-16", "%Y-%m-%d"),
                "grade": "B",
                "score": 17
            }
        ],
        "name": "Vella",
        "restaurant_id": "41704620"
    }
)

# %%
result.inserted_id
# Out:
# ObjectId('56bb523fa6289521b0bc310f')

# %%
cursor = restaurants.find({'borough': 'Manhattan'})

# %%
for document in cursor.limit(3):
    print(document)
# Out:
# {u'cuisine': u'Irish', '_id': ObjectId('56bb523ca6289521b0bbce02'), u'name': u'Dj Reynolds Pub And Restaurant', u'restaurant_id': u'30191841', u'grades': [{u'date': {u'$date': 1409961600000}, u'grade': u'A', u'score': 2}, {u'date': {u'$date': 1374451200000}, u'grade': u'A', u'score': 11}, {u'date': {u'$date': 1343692800000}, u'grade': u'A', u'score': 12}, {u'date': {u'$date': 1325116800000}, u'grade': u'A', u'score': 12}], u'address': {u'building': u'351', u'street': u'West   57 Street', u'zipcode': u'10019', u'coord': [-73.98513559999999, 40.7676919]}, u'borough': u'Manhattan'}
# {u'cuisine': u'American ', '_id': ObjectId('56bb523ca6289521b0bbce0d'), u'name': u'1 East 66Th Street Kitchen', u'restaurant_id': u'40359480', u'grades': [{u'date': {u'$date': 1399420800000}, u'grade': u'A', u'score': 3}, {u'date': {u'$date': 1367539200000}, u'grade': u'A', u'score': 4}, {u'date': {u'$date': 1335744000000}, u'grade': u'A', u'score': 6}, {u'date': {u'$date': 1324944000000}, u'grade': u'A', u'score': 0}], u'address': {u'building': u'1', u'street': u'East   66 Street', u'zipcode': u'10065', u'coord': [-73.96926909999999, 40.7685235]}, u'borough': u'Manhattan'}
# {u'cuisine': u'American ', '_id': ObjectId('56bb523ca6289521b0bbce12'), u'name': u'Glorious Food', u'restaurant_id': u'40361521', u'grades': [{u'date': {u'$date': 1409616000000}, u'grade': u'A', u'score': 12}, {u'date': {u'$date': 1387411200000}, u'grade': u'B', u'score': 16}, {u'date': {u'$date': 1369699200000}, u'grade': u'A', u'score': 9}, {u'date': {u'$date': 1354838400000}, u'grade': u'A', u'score': 13}, {u'date': {u'$date': 1332979200000}, u'grade': u'A', u'score': 11}], u'address': {u'building': u'522', u'street': u'East   74 Street', u'zipcode': u'10021', u'coord': [-73.95171, 40.767461]}, u'borough': u'Manhattan'}

# %%
cursor = restaurants.find({'grades.grade': 'B'})

# %%
cursor.count()
# Out:
# 8281

# %%
for document in cursor.limit(3):
    print(document['name'])
# Out:
# Morris Park Bake Shop
# Wendy'S
# Tov Kosher Kitchen

# %%
restaurants.find({"grades.score": {"$lt": 10}}).count()
# Out:
# 19065

# %%
restaurants.find({'cuisine': 'Italian', 'address.zipcode': '10075'}).count()
# Out:
# 16

# %%
restaurants.find({"$or": [{"cuisine": "Italian"}, {"address.zipcode": "10075"}]}).count()
# Out:
# 1154

# %%
cursor = restaurants.find().sort([
    ("borough", 1),
    ("address.zipcode", -1)
])

# %%
for document in cursor:
    print(document['borough'], document['address']['zipcode'])
# Out:
# (u'Bronx', u'11370')
# (u'Bronx', u'11370')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10475')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10474')
# (u'Bronx', u'10473')
# (u'Bronx', u'10473')
# (u'Bronx', u'10473')
# (u'Bronx', u'10473')
# (u'Bronx', u'10473')
# (u'Bronx', u'10473')
# (u'Bronx', u'10473')
# (u'Bronx', u'10473')
# (u'Bronx', u'10473')
# (u'Bronx', u'10473')
# (u'Bronx', u'10473')
# (u'Bronx', u'10473')
# (u'Bronx', u'10473')
# (u'Bronx', u'10473')
# (u'Bronx', u'10473')
# (u'Bronx', u'10473')
# (u'Bronx', u'10473')
# (u'Bronx', u'10473')
# (u'Bronx', u'10473')
# (u'Bronx', u'10473')
# (u'Bronx', u'10473')
# (u'Bronx', u'10473')
# (u'Bronx', u'10473')
# (u'Bronx', u'10473')
# (u'Bronx', u'10473')
# (u'Bronx', u'10473')
# (u'Bronx', u'10473')
# (u'Bronx', u'10473')
# (u'Bronx', u'10473')
# (u'Bronx', u'10473')
# (u'Bronx', u'10473')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10472')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10471')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10470')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10469')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10468')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10467')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10466')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10465')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10464')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10463')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10462')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10461')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10460')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10459')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10458')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10457')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10456')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10455')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10454')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10453')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10452')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# (u'Bronx', u'10451')
# ...
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10308')
# (u'Staten Island', u'10307')
# (u'Staten Island', u'10307')
# (u'Staten Island', u'10307')
# (u'Staten Island', u'10307')
# (u'Staten Island', u'10307')
# (u'Staten Island', u'10307')
# (u'Staten Island', u'10307')
# (u'Staten Island', u'10307')
# (u'Staten Island', u'10307')
# (u'Staten Island', u'10307')
# (u'Staten Island', u'10307')
# (u'Staten Island', u'10307')
# (u'Staten Island', u'10307')
# (u'Staten Island', u'10307')
# (u'Staten Island', u'10307')
# (u'Staten Island', u'10307')
# (u'Staten Island', u'10307')
# (u'Staten Island', u'10307')
# (u'Staten Island', u'10307')
# (u'Staten Island', u'10307')
# (u'Staten Island', u'10307')
# (u'Staten Island', u'10307')
# (u'Staten Island', u'10307')
# (u'Staten Island', u'10307')
# (u'Staten Island', u'10307')
# (u'Staten Island', u'10307')
# (u'Staten Island', u'10307')
# (u'Staten Island', u'10307')
# (u'Staten Island', u'10307')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10306')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10305')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10304')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10303')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10302')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')
# (u'Staten Island', u'10301')

# %%
result = restaurants.update_one(
    {"name": "Juni"},
    {
        "$set": {
            "cuisine": "American (New)",
            "lastModified": datetime.now()
        }
    }
)

# %%
result.modified_count
# Out:
# 1

# %%
result = restaurants.update_one(
    {"restaurant_id": "41156888"},
    {"$set": {"address.street": "East 31st Street"}}
)

# %%
result.modified_count
# Out:
# 1

# %%
result = restaurants.update_many(
    {"address.zipcode": "10016", "cuisine": "Other"},
    {
        "$set": {"cuisine": "Category To Be Determined"},
    }
)

# %%
result.modified_count
# Out:
# 20

# %%
result = restaurants.replace_one(
    {"restaurant_id": "41704620"},
    {
        "name": "Vella 2",
        "address": {
            "coord": [-73.9557413, 40.7720266],
            "building": "1480",
            "street": "2 Avenue",
            "zipcode": "10075"
        }
    }
)

# %%
result.modified_count
# Out:
# 1

# %%
result = restaurants.delete_many({"borough": "Manhattan"})

# %%
result.deleted_count
# Out:
# 10259

# %%
result = restaurants.delete_many({})

# %%
result.deleted_count
# Out:
# 15101

# %%
restaurants.drop()

# %%
# Re-insert all docs
restaurants.insert_many(dataset)

# %%
# Add a little class, for easier copy/paste from examples.
class Db:
    pass
db = Db()
db.restaurants = restaurants

# %%
cursor = db.restaurants.aggregate(
    [
        {"$group": {"_id": "$borough", "count": {"$sum": 1}}}
    ]
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-60fa348d4919> in <module>()
#       1 cursor = db.restaurants.aggregate(
#       2     [
# ----> 3         {"$group": {"_id": "$borough", "count": {"$sum": 1}}}
#       4     ]
#       5 )
#
# /Users/dwinston/Dropbox/personal-projects/mongo-novice-materials/env/lib/python2.7/site-packages/mongomock/collection.pyc in aggregate(self, pipeline, **kwargs)
#    1384
#    1385                                         current_val = doc_dict.get(field, 0)
# -> 1386                                         from_field = key.replace('$', '')
#    1387                                         if func == "$sum":
#    1388                                             for doc in group_list:
#
# AttributeError: 'int' object has no attribute 'replace'

# %%
# Aggregation example doesn't work with mongomock.
# Too bad. This means mongomock should definitely be a fallback option only.

# Try again using a real mongo client.
import pymongo

client = pymongo.MongoClient()
db = client.swc

# %%
! mongoimport --db swc --collection restaurants --drop --file data/primer-dataset.json
# Out:
# connected to: 127.0.0.1
# 2016-02-10T07:07:58.383-0800 dropping: swc.restaurants
# 2016-02-10T07:07:58.883-0800 check 9 25359
# 2016-02-10T07:07:58.884-0800 imported 25359 objects

# %%
cursor = db.restaurants.aggregate(
    [
        {"$group": {"_id": "$borough", "count": {"$sum": 1}}}
    ]
)

# %%
for document in cursor:
    print(document)
# Out:
# {u'count': 51, u'_id': u'Missing'}
# {u'count': 969, u'_id': u'Staten Island'}
# {u'count': 10259, u'_id': u'Manhattan'}
# {u'count': 6086, u'_id': u'Brooklyn'}
# {u'count': 5656, u'_id': u'Queens'}
# {u'count': 2338, u'_id': u'Bronx'}

# %%
cursor = db.restaurants.aggregate(
    [
        {"$match": {"borough": "Queens", "cuisine": "Brazilian"}},
        {"$group": {"_id": "$address.zipcode", "count": {"$sum": 1}}}
    ]
)

# %%
for document in cursor:
    print(document)
# Out:
# {u'count': 1, u'_id': u'11377'}
# {u'count': 1, u'_id': u'11368'}
# {u'count': 2, u'_id': u'11101'}
# {u'count': 3, u'_id': u'11106'}
# {u'count': 1, u'_id': u'11103'}

# %%
db.restaurants.create_index([("cuisine", pymongo.ASCENDING)])
# Out:
# u'cuisine_1'

# %%
db.restaurants.create_index([
    ("cuisine", pymongo.ASCENDING),
    ("address.zipcode", pymongo.DESCENDING)
])
# Out:
# u'cuisine_1_address.zipcode_-1'
